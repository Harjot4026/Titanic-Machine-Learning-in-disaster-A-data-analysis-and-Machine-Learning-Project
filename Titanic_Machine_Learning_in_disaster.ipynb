# %% [markdown]
# <a href="https://colab.research.google.com/github/Harjot4026/Titanic-Machine-Learning-in-disaster-A-data-analysis-and-Machine-Learning-Project/blob/main/Titanic_Machine_Learning_in_disaster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# In the following code we are changing the starting Index from 0 to 1.

# %%
df.index=range(1,len(df)+1)
df.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             1         0       3
# 2             2         1       1
# 3             3         1       3
# 4             4         1       1
# 5             5         0       3
# 6             6         0       3
# 7             7         0       1
# 8             8         0       3
# 9             9         1       3
# 10           10         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1                             Braund, Mr. Owen Harris    male  22.0      1
# 2   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3                              Heikkinen, Miss. Laina  female  26.0      0
# 4        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                            Allen, Mr. William Henry    male  35.0      0
# 6                                    Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# In following code we are dropping the missing values in Embarked column

# %%
df.dropna(subset=['Embarked'])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# 5              5         0       3
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1                              Braund, Mr. Owen Harris    male  22.0      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3                               Heikkinen, Miss. Laina  female  26.0      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   889.000000  889.000000  889.000000  889.000000  889.000000
# mean    446.000000    0.382452    2.311586   29.315152    0.524184
# std     256.998173    0.486260    0.834700   12.984932    1.103705
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     224.000000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.000000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  889.000000  889.000000
# mean     0.382452   32.096681
# std      0.806761   49.697504
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Age'].fillna(df['Age'].median(),inplace=True)

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    340
# Name: Survived, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    214
# 2    184
# Name: Pclass, dtype: int64

# %%
#df.drop(['Cabin','Ticket'],axis=1,inplace=True)
print('Already deleted these rows as they are not beneficial in analysis')
# Out:
# Already deleted these rows as they are not beneficial in analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Survival rate by class
sns.barplot(x='Pclass',y='Survived',data=df)
plt.show()

# %%
sns.violinplot(x='Survived',y='Age',data=df)
plt.title('Age Distribution by Survival')
plt.xlabel('Survived')
plt.ylabel('Age')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %%
sns.heatmap(df.corr(),annot=True, cmap='coolwarm')
plt.show()
# Out:
# <ipython-input-52-044cd59bbb62>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True, cmap='coolwarm')

# %%
sns.countplot(x='Sex',hue='Survived',data=df, palette="Set2")
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.boxplot(x='Pclass',y='Age',data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
#handling categorical variables
df['Sex']=df['Sex'].map({'male':0, 'female':1})
df=pd.get_dummies(df,columns=['Embarked'],drop_first=True)

#feature selection
features=['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked_Q', 'Embarked_S']
X=df[features]
Y=df['Survived']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

#create and train the model
model=DecisionTreeClassifier(random_state=42)
model.fit(X_train,Y_train)

#prediction
pred=model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(Y_test, pred)
print(f'Accuracy: {accuracy:.2f}')

# Confusion matrix and classification report
print('\nConfusion Matrix:')
print(confusion_matrix(Y_test, pred))

print('\nClassification Report:')
print(classification_report(Y_test, pred))
# Out:
# Accuracy: 0.75
#
# Confusion Matrix:
# [[82 27]
#  [18 51]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.75      0.78       109
#            1       0.65      0.74      0.69        69
#
#     accuracy                           0.75       178
#    macro avg       0.74      0.75      0.74       178
# weighted avg       0.76      0.75      0.75       178

# %%
# Assuming model is already trained
# Assuming features=['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked_Q', 'Embarked_S']

# Provide values for each feature
user_data = {
    'Pclass': [1],
    'Sex': [1],
    'Age': [40],
    'SibSp': [0],
    'Parch': [1],
    'Fare': [11.133],
    'Embarked_Q': [0],
    'Embarked_S': [1]
}

# Create a DataFrame from user input
user_data_df = pd.DataFrame(user_data)

# Convert categorical variables to numerical using the same preprocessing as training data
#label_encoder = LabelEncoder()
#user_data_df['Sex'] = label_encoder.fit_transform(user_data_df['Sex'])

# Make predictions for the user input
user_predictions = model.predict(user_data_df)

# Display the prediction
print("Predicted Survived value for the user input:")
print(user_predictions)
# Out:
# Predicted Survived value for the user input:
# [1]

# %% [markdown]
# Now we will take any input from the user and predict the value

# %%
print("Enter Sex and Embarked in binary")
user_data={}

for feature in features:
  user_input=input(f"Enter the value for {feature}: ")
  user_data[feature]=[user_input]

user_data_df=pd.DataFrame(user_data)

# Make predictions for the user input
user_predictions = model.predict(user_data_df)

# Display the prediction
print("Predicted Survived value for the user input:")
print(user_predictions)
# Out:
# Enter Sex and Embarked in binary
# Enter the value for Pclass: 3
# Enter the value for Sex: 0
# Enter the value for Age: 40
# Enter the value for SibSp: 1
# Enter the value for Parch: 0
# Enter the value for Fare: 7.25
# Enter the value for Embarked_Q: 1
# Enter the value for Embarked_S: 0
# Predicted Survived value for the user input:
# [0]

# %% [markdown]
# Simple data Analysis and Machine Learning prediction Project is completed . You can try with the another Model of ML.
